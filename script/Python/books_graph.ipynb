# %%
import networkx as nx
import csv
import matplotlib.pyplot as plt

# %%
class Book:
    def __init__(self, title, authors, publication_date):
        self.title = title
        self.authors = authors
        self.publication_date = publication_date

# %%
with open("F:\\UCL 巴莱\\学习\\RC11\\软件学习\\Python\\Wanting-Ding---Yunyun-Guo\\books.csv") as csvfile:
    reader = csv.reader(csvfile)
    print(next(reader))
# Out:
# ['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13', 'language_code', '  num_pages', 'ratings_count', 'text_reviews_count', 'publication_date', 'publisher']

# %%
with open("F:\\UCL 巴莱\\学习\\RC11\\软件学习\\Python\\Wanting-Ding---Yunyun-Guo\\books.csv",encoding='UTF-8') as csvfile:
    reader = csv.reader(csvfile)
    rows = 0
    for r in reader:
        rows +=1 
    print(rows)
# Out:
# 11128

# %%
Books = []
with open("F:\\UCL 巴莱\\学习\\RC11\\软件学习\\Python\\Wanting-Ding---Yunyun-Guo\\books.csv",encoding='UTF-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        title = row['title']
        authors = row['authors']
        publication_date = row['publication_date']
        Books.append(Book(title, authors, publication_date))

# %%
BookGraph = nx.Graph()

# %%
bookSubset = Books[0:1800] #take first 1800 books

# %%
for b in bookSubset:
    BookGraph.add_node(f)

# %%
for b1 in bookSubset:
    for b2 in bookSubset:
        if not b1 == b2:
            if b1.authors == b2.authors:
                BookGraph.add_edge(b1,b2)
            if b1.publication_date == b2.publication_date:
                BookGraph.add_edge(b1,b2)

# %%
options = {'node_color':'black', 'edge_color':'grey', 'node_size':10, 'width':1}
plt.figure(1, figsize = (30, 30))
nx.draw(BookGraph, **options)

# %% [markdown]
# This graph shows connection between books based on their authors and publication dates.
